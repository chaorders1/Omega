# %%
import requests, os

headers = {
    'Authorization': os.getenv("SPIDER_API_KEY"),
    'Content-Type': 'application/json',
}

json_data = {"limit":25,"return_format":"markdown","url":"https://www.youtube.com/watch?v=7kbQnLN2y_I"}

response = requests.post('https://api.spider.cloud/crawl', 
  headers=headers, json=json_data)

print(response.json())
# Out:
# [{'content': 'YouTube\n![](data:image/png;base64,...)\n', 'costs': {'ai_cost': 0, 'compute_cost': 0.0001, 'file_cost': 0.0005, 'total_cost': 0.0007, 'transform_cost': 0.0001}, 'error': None, 'status': 200, 'url': 'https://www.youtube.com/watch?v=7kbQnLN2y_I'}]

# %%
print(json_data)
# Out:
# {'limit': 25, 'return_format': 'markdown', 'url': 'https://www.youtube.com/watch?v=7kbQnLN2y_I'}
